# %% [markdown]
# ## 1. mongodb 문법 실습
#
# * cine21 배우 랭킹 사이트 크롤링
#   - 사이트 주소: http://www.cine21.com/rank/person/
#   - 요청 방식 확인 방법: 크롬 개발자 모드로 들어가서, Network -> content 페이지의 요청 방식 확인
#     - Request URL: http://www.cine21.com/rank/person/content
#     - Request Method: POST
#     - Form data
#       - section = 'actor'
#       - period_start = '2018-08'
#       - gender = 'all'
#       - page = 3

# %% [markdown]
# #### 배우 랭킹 및 상세 정보 크롤링 및 mongodb 저장 (full source)

# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import re

conn = pymongo.MongoClient()
actor_db = conn.cine21
actor_collection = actor_db.actor_collection

actors_info_list = list()

cine21_url = 'http://www.cine21.com/rank/person/content'
post_data = dict()
post_data['section'] = 'actor'
post_data['period_start'] = '2018-08'
post_data['gender'] = 'all'

for index in range(1, 21):
    post_data['page'] = index

    res = requests.post(cine21_url, data=post_data)
    soup = BeautifulSoup(res.content, 'html.parser')

    actors = soup.select('li.people_li div.name')
    hits = soup.select('ul.num_info > li > strong')
    movies = soup.select('ul.mov_list')
    rankings = soup.select('li.people_li > span.grade')
    
    for index, actor in enumerate(actors):
        actor_name = re.sub('\(\w*\)', '', actor.text)
        actor_hits = int(hits[index].text.replace(',', ''))
        movie_titles = movies[index].select('li a span')
        movie_title_list = list()
        for movie_title in movie_titles:
            movie_title_list.append(movie_title.text)
        actor_info_dict = dict()
        actor_info_dict['배우이름'] = actor_name
        actor_info_dict['흥행지수'] = actor_hits
        actor_info_dict['출연영화'] = movie_title_list
        actor_info_dict['랭킹'] = rankings[index].text

        actor_link = 'http://www.cine21.com' + actor.select_one('a').attrs['href']
        response_actor = requests.get(actor_link)
        soup_actor = BeautifulSoup(response_actor.content, 'html.parser')
        default_info = soup_actor.select_one('ul.default_info')
        actor_details = default_info.select('li')

        for actor_item in actor_details:
            actor_item_field = actor_item.select_one('span.tit').text
            actor_item_value = re.sub('<span.*?>.*?</span>', '', str(actor_item))
            actor_item_value = re.sub('<.*?>', '', actor_item_value)
            actor_info_dict[actor_item_field] = actor_item_value
        actors_info_list.append(actor_info_dict)
        
actor_collection.insert_many(actors_info_list)

# %% [markdown]
# #### mongodb 접속 기본 코드

# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import re

conn = pymongo.MongoClient()
actor_db = conn.cine21
actor_collection = actor_db.actor_collection

actor_collection.find_one({})
docs = actor_collection.find({}).limit(3)
for doc in docs:
    print (doc)
actor = actor_collection
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1a'), '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '배우이름': '황정민', '흥행지수': 78066, '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라'], '랭킹': 1}
# {'_id': ObjectId('6019112ffd9a8148c2183d1b'), '직업': '배우', '성별': '남', '홈페이지': '\nhttp://www.artistcompany.co.kr/portfolio-item/lee-jung-jae/\n', '소속사': '아티스트컴퍼니', '배우이름': '이정재', '흥행지수': 52049, '출연영화': ['다만 악에서 구하소서', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연', '사바하', '도둑들'], '랭킹': 2}
# {'_id': ObjectId('6019112ffd9a8148c2183d1c'), '다른 이름': '엄홍식', '직업': '배우', '생년월일': '1986-10-06', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/hongsick/\nhttps://twitter.com/seeksik\n', '신장/체중': '178cm, 60kg', '학교': '단국대학교 연극', '취미': '피아노 연주, 인터넷 게임, 영화, 음악감상', '특기': '스노우보드, 수영', '배우이름': '유아인', '흥행지수': 42530, '출연영화': ['#살아있다', '소리도 없이', '버닝', '사도'], '랭킹': 3}

# %% [markdown]
# ### 1.1. 컬럼명 변경
# * 저장되 있는 mongodb 데이터의 컬럼명을 변경하는 방법
# * update_one()/update_many() 함수 활용

# %%
actor_collection.update_many ({}, { '$rename': {'다른 이름': '다른이름'} })

# %%
docs = actor_collection.find({}).limit(3)
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1a'), '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '배우이름': '황정민', '흥행지수': 78066, '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라'], '랭킹': 1}
# {'_id': ObjectId('6019112ffd9a8148c2183d1b'), '직업': '배우', '성별': '남', '홈페이지': '\nhttp://www.artistcompany.co.kr/portfolio-item/lee-jung-jae/\n', '소속사': '아티스트컴퍼니', '배우이름': '이정재', '흥행지수': 52049, '출연영화': ['다만 악에서 구하소서', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연', '사바하', '도둑들'], '랭킹': 2}
# {'_id': ObjectId('6019112ffd9a8148c2183d1c'), '직업': '배우', '생년월일': '1986-10-06', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/hongsick/\nhttps://twitter.com/seeksik\n', '신장/체중': '178cm, 60kg', '학교': '단국대학교 연극', '취미': '피아노 연주, 인터넷 게임, 영화, 음악감상', '특기': '스노우보드, 수영', '배우이름': '유아인', '흥행지수': 42530, '출연영화': ['#살아있다', '소리도 없이', '버닝', '사도'], '랭킹': 3, '다른이름': '엄홍식'}

# %% [markdown]
# #### 참고: collection 변수명 변경

# %%
actor = actor_collection

# %% [markdown]
# ### 1.2 find의 다양한 문법 - sort

# %%
docs = actor_collection.find({}).sort('생년월일', pymongo.DESCENDING).limit(10)
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d3e'), '직업': '배우', '생년월일': '2012-03-12', '성별': '여', '배우이름': '박소이', '흥행지수': 6047, '출연영화': ['담보', '호텔 레이크'], '랭킹': 37}
# {'_id': ObjectId('6019112ffd9a8148c2183d98'), '직업': '배우', '생년월일': '2011-11-08', '성별': '남', '배우이름': '정현준', '흥행지수': 1285, '출연영화': ['기생충', '이웃사촌'], '랭킹': 127}
# {'_id': ObjectId('6019112ffd9a8148c218412c'), '직업': '배우', '생년월일': '2011-10-11', '성별': '여', '배우이름': '주예림', '흥행지수': 1, '출연영화': ['우리집'], '랭킹': 1043}
# {'_id': ObjectId('6019112ffd9a8148c218412f'), '직업': '배우', '생년월일': '2011-10-11', '성별': '여', '배우이름': '주예림', '흥행지수': 1, '출연영화': ['우리집'], '랭킹': 1046}
# {'_id': ObjectId('6019112ffd9a8148c2183e69'), '직업': '배우', '생년월일': '2011-02-21', '성별': '남', '배우이름': '이린하', '흥행지수': 81, '출연영화': ['나는보리'], '랭킹': 336}
# {'_id': ObjectId('6019112ffd9a8148c2183eec'), '직업': '배우', '생년월일': '2010-10-01', '성별': '여', '배우이름': '김보민', '흥행지수': 24, '출연영화': ['담쟁이', '생일'], '랭킹': 467}
# {'_id': ObjectId('6019112ffd9a8148c2183da9'), '직업': '배우', '생년월일': '2010-09-29', '성별': '남', '배우이름': '이경훈', '흥행지수': 949, '출연영화': ['저 산 너머'], '랭킹': 144}
# {'_id': ObjectId('6019112ffd9a8148c2183ede'), '직업': '배우', '생년월일': '2010-02-03', '성별': '여', '배우이름': '장재희', '흥행지수': 26, '출연영화': ['종이꽃'], '랭킹': 453, '다른이름': 'JangJaehee'}
# {'_id': ObjectId('6019112ffd9a8148c21840c4'), '직업': '배우', '생년월일': '2009-06-27', '성별': '남', '배우이름': '임한빈', '흥행지수': 2, '출연영화': ['저 산 너머'], '랭킹': 939}
# {'_id': ObjectId('6019112ffd9a8148c2183d35'), '직업': '배우', '생년월일': '2009-06-26', '성별': '여', '배우이름': '허율', '흥행지수': 7543, '출연영화': ['클로젯'], '랭킹': 28}

# %% [markdown]
# ### 1.3 find의 다양한 문법 - exists

# %%
docs = actor.find({'특기': {'$exists':True}}).sort('흥행지수').limit(5)
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c218421b'), '직업': '배우', '생년월일': '1974-04-05', '성별': '남', '홈페이지': '\nhttps://twitter.com/zhao74\nhttps://instagram.com/taewoong74\n', '신장/체중': '181cm, 70kg', '학교': '국민대학교 공연예술학부 재학', '취미': '여행, 드라이브', '특기': '수영, 스킨스쿠버, 승마', '소속사': '키이스트', '배우이름': '엄태웅', '흥행지수': 0, '출연영화': ['건축학개론', '시라노; 연애조작단'], '랭킹': 1282}
# {'_id': ObjectId('6019112ffd9a8148c218423c'), '직업': '배우', '생년월일': '1957-10-01', '성별': '남', '홈페이지': '\nhttps://instagram.com/river_stone_rain/\n', '신장/체중': '176cm, 75kg', '학교': '동국대학교 연극영화학', '취미': '음악감상', '특기': '축구', '배우이름': '강석우', '흥행지수': 0, '출연영화': ['장마'], '랭킹': 1315, '다른이름': '강만홍'}
# {'_id': ObjectId('6019112ffd9a8148c2184233'), '직업': '배우', '생년월일': '1944-06-10', '성별': '남', '신장/체중': '176cm, 82kg', '학교': '명지대학교 영문학', '취미': '낚시,골프', '특기': '다이빙', '배우이름': '백일섭', '흥행지수': 0, '출연영화': ['별들의 고향', '삼포가는 길'], '랭킹': 1306}
# {'_id': ObjectId('6019112ffd9a8148c21841ee'), '직업': '가수', '생년월일': '1987-02-24', '성별': '남', '신장/체중': '181cm, 65kg', '학교': '백제예술대학 실용음악과', '취미': '음악감상, 농구, 독서', '특기': '마술', '소속사': 'DSP엔터테인먼트', '배우이름': '김규종', '흥행지수': 0, '출연영화': ['이 안에 외계인이 있다'], '랭킹': 1237, '다른이름': 'SS501'}
# {'_id': ObjectId('6019112ffd9a8148c21841df'), '원어명': '조은지', '직업': '배우', '생년월일': '1981-02-10', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/soda_c_5/\n', '신장/체중': '168cm, 48kg', '취미': '쇼핑', '특기': '바이올린 연주', '배우이름': '조은지', '흥행지수': 0, '출연영화': ['카센타', '개를 훔치는 완벽한 방법'], '랭킹': 1222}

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="blue" size="4em">실습</font><br>
# 생년월일이 없는 doc의 actor_name 만 출력하기
# </div>

# %%
docs = actor.find({'생년월일': {'$exists':False}}, {'배우이름':1, '_id':0})
for doc in docs:
    print (doc)
# Out:
# {'배우이름': '이정재'}
# {'배우이름': '정우성'}
# {'배우이름': '고아성'}
# {'배우이름': '이솜'}
# {'배우이름': '장동주'}
# {'배우이름': '신정근'}
# {'배우이름': '염정아'}
# {'배우이름': '정만식'}
# {'배우이름': '김소진'}
# {'배우이름': '배성우'}
# {'배우이름': '문승아'}
# {'배우이름': '오혜원'}
# {'배우이름': '이유영'}
# {'배우이름': '한이진'}
# {'배우이름': '신용우'}
# {'배우이름': '이진주'}
# {'배우이름': '남도형'}
# {'배우이름': '문남숙'}
# {'배우이름': '김경희'}
# {'배우이름': '장민혁'}
# {'배우이름': '조현정'}
# {'배우이름': '이소영'}
# {'배우이름': '최승훈'}
# {'배우이름': '홍진욱'}
# {'배우이름': '이중옥'}
# {'배우이름': '조경이'}
# {'배우이름': '전태열'}
# {'배우이름': '소연'}
# {'배우이름': '강시현'}
# {'배우이름': '양흥주'}
# {'배우이름': '이봉근'}
# {'배우이름': '이창민'}
# {'배우이름': '정무성'}
# {'배우이름': '김서영'}
# {'배우이름': '김은아'}
# {'배우이름': '이용규'}
# {'배우이름': '김순규'}
# {'배우이름': '박현영'}
# {'배우이름': '정재헌'}
# {'배우이름': '하성용'}
# {'배우이름': '이봉련'}
# {'배우이름': '정유정'}
# {'배우이름': '오인실'}
# {'배우이름': '김현수'}
# {'배우이름': '최정운'}
# {'배우이름': '김율'}
# {'배우이름': '김의성'}
# {'배우이름': '김정은'}
# {'배우이름': '김유림'}
# {'배우이름': '배상우'}
# {'배우이름': '허성재'}
# {'배우이름': '박리나'}
# {'배우이름': '이명호'}
# {'배우이름': '김하연'}
# {'배우이름': '문창길'}
# {'배우이름': '강은애'}
# {'배우이름': '박승준'}
# {'배우이름': '이지예'}
# {'배우이름': '박윤진'}
# {'배우이름': '한경화'}
# {'배우이름': '박재한'}
# {'배우이름': '박영재'}
# {'배우이름': '김새벽'}
# {'배우이름': '장하은'}
# {'배우이름': '채지희'}
# {'배우이름': '천정은'}
# {'배우이름': '전채은'}
# {'배우이름': '홍수정'}
# {'배우이름': '김현지'}
# {'배우이름': '최준원'}
# {'배우이름': '서다혜'}
# {'배우이름': '허지나'}
# {'배우이름': '홍주성'}
# {'배우이름': '이영란'}
# {'배우이름': '김상동'}
# {'배우이름': '서영재'}
# {'배우이름': '최용진'}
# {'배우이름': '윤승희'}
# {'배우이름': '김다희'}
# {'배우이름': '이봉준'}
# {'배우이름': '오창경'}
# {'배우이름': '최정윤'}
# {'배우이름': '민승연'}
# {'배우이름': '최미경'}
# {'배우이름': '장리우'}
# {'배우이름': '구윤영'}
# {'배우이름': '오수경'}
# {'배우이름': '이지연'}
# {'배우이름': '간미연'}
# {'배우이름': '한상혁'}
# {'배우이름': '이선희'}
# {'배우이름': '곽민규'}
# {'배우이름': '홍근택'}
# {'배우이름': '허예은'}
# {'배우이름': '김소희'}
# {'배우이름': '강성우'}
# {'배우이름': '황유림'}
# {'배우이름': '고구인'}
# {'배우이름': '강구한'}
# {'배우이름': '김현욱'}
# {'배우이름': '곽규미'}
# {'배우이름': '이재원'}
# {'배우이름': '김민주'}
# {'배우이름': '차지현'}
# {'배우이름': '박상증'}
# {'배우이름': '한태의'}
# {'배우이름': '윤금선아'}
# {'배우이름': '설영범'}
# {'배우이름': '정주원'}
# {'배우이름': '이원찬'}
# {'배우이름': '차지현'}
# {'배우이름': '송준석'}
# {'배우이름': '신신애'}
# {'배우이름': '정지혜'}
# {'배우이름': '안효민'}
# {'배우이름': '이명희'}
# {'배우이름': '임희철'}
# {'배우이름': '오스카'}
# {'배우이름': '이상범'}
# {'배우이름': '정하진'}
# {'배우이름': '장준현'}
# {'배우이름': '이새아'}
# {'배우이름': '강민준'}
# {'배우이름': '지성원'}
# {'배우이름': '구윤주'}
# {'배우이름': '김영은'}
# {'배우이름': '이재범'}
# {'배우이름': '김동균'}
# {'배우이름': '강두'}
# {'배우이름': '한신'}
# {'배우이름': '양소민'}
# {'배우이름': '김사라'}
# {'배우이름': '옥자연'}
# {'배우이름': '신철진'}
# {'배우이름': '김혜성'}
# {'배우이름': '차지혁'}
# {'배우이름': '이서윤'}
# {'배우이름': '김채하'}
# {'배우이름': '최홍일'}
# {'배우이름': '박성훈'}
# {'배우이름': '윤정욱'}
# {'배우이름': '박지아'}
# {'배우이름': '기호'}
# {'배우이름': '한흥만'}
# {'배우이름': '유순웅'}
# {'배우이름': '조선기'}
# {'배우이름': '김윤성'}
# {'배우이름': '박세준'}
# {'배우이름': '테오'}
# {'배우이름': '한해인'}
# {'배우이름': '이지현'}
# {'배우이름': '김주영'}
# {'배우이름': '사성웅'}
# {'배우이름': '유태균'}
# {'배우이름': '방성영'}
# {'배우이름': '지웅'}
# {'배우이름': '옥윤중'}
# {'배우이름': '이경태'}
# {'배우이름': '이광자'}
# {'배우이름': '안소이'}
# {'배우이름': '이광자'}
# {'배우이름': '인탁'}
# {'배우이름': '곽동건'}
# {'배우이름': '강애심'}
# {'배우이름': '김홍표'}
# {'배우이름': '강인성'}
# {'배우이름': '설혜인'}
# {'배우이름': '전진아'}
# {'배우이름': '박수연'}
# {'배우이름': '김준형'}
# {'배우이름': '박경순'}
# {'배우이름': '정가영'}
# {'배우이름': '이인석'}
# {'배우이름': '권성혁'}
# {'배우이름': '강선숙'}
# {'배우이름': '김재록'}
# {'배우이름': '강은우'}
# {'배우이름': '백재민'}
# {'배우이름': '채민지'}
# {'배우이름': '김경재'}
# {'배우이름': '이상각'}
# {'배우이름': '공경은'}
# {'배우이름': '오동민'}
# {'배우이름': '서윤아'}
# {'배우이름': '임은정'}
# {'배우이름': '변중희'}
# {'배우이름': '고관재'}
# {'배우이름': '이운숙'}
# {'배우이름': '김초인'}
# {'배우이름': '유호한'}
# {'배우이름': '김초인'}
# {'배우이름': '이동훈'}
# {'배우이름': '삼숙'}
# {'배우이름': '권미아'}
# {'배우이름': '황정윤'}
# {'배우이름': '홍근진'}
# {'배우이름': '최수인'}
# {'배우이름': '김정균'}
# {'배우이름': '권창욱'}
# {'배우이름': '윤종기'}
# {'배우이름': '박혜나'}
# {'배우이름': '정승욱'}
# {'배우이름': '김예림'}
# {'배우이름': '임형국'}
# {'배우이름': '차유경'}
# {'배우이름': '홍희용'}
# {'배우이름': '김현심'}
# {'배우이름': '김경덕'}
# {'배우이름': '정상윤'}
# {'배우이름': '장미'}
# {'배우이름': '이재인'}
# {'배우이름': '윤승욱'}
# {'배우이름': '장서화'}
# {'배우이름': '김용준'}
# {'배우이름': '김기형'}
# {'배우이름': '조병만'}
# {'배우이름': '김동주'}
# {'배우이름': '이승원'}
# {'배우이름': '이채담'}
# {'배우이름': '이채담'}
# {'배우이름': '원현준'}
# {'배우이름': '신선해'}
# {'배우이름': '김수연'}
# {'배우이름': '이승호'}
# {'배우이름': '이진리'}
# {'배우이름': '이미자'}
# {'배우이름': '송희준'}
# {'배우이름': '이규정'}
# {'배우이름': '이정현'}
# {'배우이름': '서문석'}
# {'배우이름': '이동훈'}
# {'배우이름': '김익태'}
# {'배우이름': '문용일'}
# {'배우이름': '임선우'}
# {'배우이름': '조슬아'}
# {'배우이름': '우고나'}
# {'배우이름': '이현행'}
# {'배우이름': '시영준'}
# {'배우이름': '차희재'}
# {'배우이름': '최석필'}
# {'배우이름': '우돈기'}
# {'배우이름': '유용우'}
# {'배우이름': '정상현'}
# {'배우이름': '이슬'}
# {'배우이름': '김리흔'}
# {'배우이름': '이예성'}
# {'배우이름': '한은진'}
# {'배우이름': '이호산'}
# {'배우이름': '이다슬'}
# {'배우이름': '황현빈'}
# {'배우이름': '전후석'}
# {'배우이름': '하준호'}
# {'배우이름': '김승비'}
# {'배우이름': '이정수'}
# {'배우이름': '김희연'}
# {'배우이름': '박미성'}
# {'배우이름': '강계열'}
# {'배우이름': '김조연'}
# {'배우이름': '김조연'}
# {'배우이름': '이재웅'}
# {'배우이름': '이옥주'}
# {'배우이름': '숲이아'}
# {'배우이름': '최원균'}
# {'배우이름': '최원균'}
# {'배우이름': '형영선'}
# {'배우이름': '설지윤'}
# {'배우이름': '송명진'}
# {'배우이름': '민채은'}
# {'배우이름': '최영열'}
# {'배우이름': '최성호'}
# {'배우이름': '이대열'}
# {'배우이름': '하윤경'}
# {'배우이름': '김성희'}
# {'배우이름': '김창은'}
# {'배우이름': '신지이'}
# {'배우이름': '김창은'}
# {'배우이름': '신지이'}
# {'배우이름': '윤건일'}
# {'배우이름': '박기태'}
# {'배우이름': '김단미'}
# {'배우이름': '김나연'}
# {'배우이름': '유이화'}
# {'배우이름': '김옥경'}
# {'배우이름': '이은심'}
# {'배우이름': '김미향'}
# {'배우이름': '편한셈'}
# {'배우이름': '오은주'}
# {'배우이름': '이종국'}
# {'배우이름': '탁원정'}
# {'배우이름': '이삼순'}
# {'배우이름': '최성관'}
# {'배우이름': '홍승이'}
# {'배우이름': '홍승이'}
# {'배우이름': '최준우'}
# {'배우이름': '최준우'}
# {'배우이름': '김복자'}
# {'배우이름': '방수일'}
# {'배우이름': '김진희'}
# {'배우이름': '선우일란'}
# {'배우이름': '김병순'}
# {'배우이름': '김진희'}
# {'배우이름': '이영아'}
# {'배우이름': '이순도'}
# {'배우이름': '오영일'}
# {'배우이름': '주남정'}
# {'배우이름': '최진욱'}
# {'배우이름': '이경민'}
# {'배우이름': '김대건'}
# {'배우이름': '이경준'}
# {'배우이름': '김대건'}
# {'배우이름': '이경준'}
# {'배우이름': '노율'}
# {'배우이름': '한은선'}
# {'배우이름': '백지훈'}
# {'배우이름': '이주예'}
# {'배우이름': '이옥선'}
# {'배우이름': '김영현'}
# {'배우이름': '김지수'}
# {'배우이름': '서월영'}
# {'배우이름': '전현경'}
# {'배우이름': '트위스트 김'}
# {'배우이름': '문석범'}
# {'배우이름': '방은정'}
# {'배우이름': '트위스트 김'}
# {'배우이름': '문석범'}
# {'배우이름': '트위스트 김'}
# {'배우이름': '문석범'}
# {'배우이름': '서정연'}
# {'배우이름': '이용수'}
# {'배우이름': '서정연'}
# {'배우이름': '이용수'}
# {'배우이름': '송재룡'}
# {'배우이름': '양훈'}
# {'배우이름': '성소민'}
# {'배우이름': '송지운'}
# {'배우이름': '이소연'}
# {'배우이름': '이인세'}
# {'배우이름': '류승곤'}
# {'배우이름': '김순덕'}
# {'배우이름': '류승곤'}
# {'배우이름': '김순덕'}
# {'배우이름': '박상준'}
# {'배우이름': '최무성'}
# {'배우이름': '안인숙'}
# {'배우이름': '김성옥'}
# {'배우이름': '안인숙'}
# {'배우이름': '김성옥'}
# {'배우이름': '최현'}
# {'배우이름': '최현'}
# {'배우이름': '박건주'}
# {'배우이름': '박건주'}
# {'배우이름': '윤인자'}
# {'배우이름': '조주경'}
# {'배우이름': '이주연'}
# {'배우이름': '강백수'}
# {'배우이름': '윤인자'}
# {'배우이름': '왕평'}
# {'배우이름': '현석'}
# {'배우이름': '현석'}
# {'배우이름': '이민'}
# {'배우이름': '강일출'}
# {'배우이름': '김정기'}
# {'배우이름': '강승완'}
# {'배우이름': '박용철'}
# {'배우이름': '박금분'}
# {'배우이름': '장성호'}
# {'배우이름': '선정엽'}
# {'배우이름': '최원정'}
# {'배우이름': '황윤'}
# {'배우이름': '최희진'}
# {'배우이름': '최휘찬'}
# {'배우이름': '박형수'}
# {'배우이름': '서영주'}
# {'배우이름': '황윤'}
# {'배우이름': '김승태'}
# {'배우이름': '박선영'}
# {'배우이름': '박옥선'}
# {'배우이름': '마흥식'}
# {'배우이름': '박예영'}
# {'배우이름': '조시내'}
# {'배우이름': '송미림'}
# {'배우이름': '박선영'}
# {'배우이름': '곽자형'}
# {'배우이름': '조시내'}
# {'배우이름': '김충길'}
# {'배우이름': '김춘기'}
# {'배우이름': '김춘기'}
# {'배우이름': '김상순'}
# {'배우이름': '김영환'}
# {'배우이름': '옥수분'}
# {'배우이름': '이규성'}
# {'배우이름': '윤재'}
# {'배우이름': '강재철'}
# {'배우이름': '윤재'}
# {'배우이름': '강재철'}
# {'배우이름': '강금연'}
# {'배우이름': '박민상'}
# {'배우이름': '강문'}
# {'배우이름': '성민철'}
# {'배우이름': '강문'}
# {'배우이름': '강문'}
# {'배우이름': '성민철'}
# {'배우이름': '박민상'}
# {'배우이름': '지돌이'}
# {'배우이름': '신일용'}
# {'배우이름': '복혜숙'}
# {'배우이름': '박월선'}
# {'배우이름': '복혜숙'}
# {'배우이름': '허인영'}
# {'배우이름': '정재광'}
# {'배우이름': '허인영'}
# {'배우이름': '정재광'}
# {'배우이름': '배제기'}
# {'배우이름': '오민정'}
# {'배우이름': '김지훈'}
# {'배우이름': '노수산나'}
# {'배우이름': '김아현'}
# {'배우이름': '이수현'}
# {'배우이름': '김기춘'}
# {'배우이름': '김세동'}
# {'배우이름': '김기춘'}
# {'배우이름': '김세동'}
# {'배우이름': '이현'}
# {'배우이름': '김유리'}
# {'배우이름': '강도하'}
# {'배우이름': '하지나'}
# {'배우이름': '이주원'}
# {'배우이름': '여무영'}
# {'배우이름': '김두선'}
# {'배우이름': '유영국'}
# {'배우이름': '김혜인'}
# {'배우이름': '임형태'}
# {'배우이름': '강도하'}
# {'배우이름': '하지나'}
# {'배우이름': '이주원'}
# {'배우이름': '여무영'}
# {'배우이름': '현숙희'}
# {'배우이름': '김도희'}
# {'배우이름': '한유정'}
# {'배우이름': '강희'}
# {'배우이름': '김운하'}
# {'배우이름': '장송미'}
# {'배우이름': '김유미'}
# {'배우이름': '이용이'}
# {'배우이름': '최은애'}
# {'배우이름': '고은아'}
# {'배우이름': '박누가'}
# {'배우이름': '최정현'}
# {'배우이름': '이용이'}
# {'배우이름': '최은애'}
# {'배우이름': '고은아'}
# {'배우이름': '최정현'}
# {'배우이름': '박누가'}
# {'배우이름': '채연희'}
# {'배우이름': '한재덕'}
# {'배우이름': '김정란'}
# {'배우이름': '이민아'}
# {'배우이름': '이원순'}
# {'배우이름': '남정희'}
# {'배우이름': '배춘희'}
# {'배우이름': '이승훈'}
# {'배우이름': '조재성'}
# {'배우이름': '이해룡'}
# {'배우이름': '\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n">\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n'}
# {'배우이름': '김주복'}
# {'배우이름': '박복형'}
# {'배우이름': '이승훈'}
# {'배우이름': '차종수'}
# {'배우이름': '오기환'}
# {'배우이름': '오기철'}
# {'배우이름': '이해룡'}
# {'배우이름': '\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n">\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n'}
# {'배우이름': '김주복'}
# {'배우이름': '박복형'}
# {'배우이름': '이승훈'}
# {'배우이름': '조재성'}
# {'배우이름': '이장욱'}
# {'배우이름': '차종수'}
# {'배우이름': '오기환'}
# {'배우이름': '오기철'}
# {'배우이름': '유순철'}
# {'배우이름': '이장욱'}
# {'배우이름': '서정규'}
# {'배우이름': '이강갑'}
# {'배우이름': '김용학'}
# {'배우이름': '박규채'}
# {'배우이름': '서윤선'}
# {'배우이름': '김도완'}
# {'배우이름': '김용순'}
# {'배우이름': '김호원'}
# {'배우이름': '박지홍'}
# {'배우이름': '송유담'}
# {'배우이름': '석인수'}
# {'배우이름': '최근모'}
# {'배우이름': '박세은'}
# {'배우이름': '정인하'}
# {'배우이름': '김용순'}
# {'배우이름': '김호원'}
# {'배우이름': '박지홍'}
# {'배우이름': '민윤재'}
# {'배우이름': '민윤재'}
# {'배우이름': '이예민'}
# {'배우이름': '유안'}
# {'배우이름': '강미애'}
# {'배우이름': '이민자'}
# {'배우이름': '나정옥'}
# {'배우이름': '문미봉'}
# {'배우이름': '강미애'}
# {'배우이름': '송유담'}
# {'배우이름': '석인수'}
# {'배우이름': '최근모'}
# {'배우이름': '김예원'}
# {'배우이름': '조민경'}
# {'배우이름': '이향'}
# {'배우이름': '허재원'}
# {'배우이름': '주석희'}
# {'배우이름': '최숙진'}
# {'배우이름': '허정도'}
# {'배우이름': '김기종'}
# {'배우이름': '정재웅'}
# {'배우이름': '박도연'}
# {'배우이름': '박근수'}
# {'배우이름': '한신화'}
# {'배우이름': '채재일'}
# {'배우이름': '정형석'}
# {'배우이름': '주유랑'}
# {'배우이름': '김예원'}
# {'배우이름': '조민경'}
# {'배우이름': '홍다미'}
# {'배우이름': '신예주'}
# {'배우이름': '최재호'}
# {'배우이름': '오세현'}
# {'배우이름': '박유밀'}
# {'배우이름': '김세정'}
# {'배우이름': '채재일'}
# {'배우이름': '정형석'}
# {'배우이름': '주유랑'}
# {'배우이름': '최원경'}
# {'배우이름': '김준원'}
# {'배우이름': '김주희'}
# {'배우이름': '김순자'}
# {'배우이름': '박유밀'}
# {'배우이름': '박도연'}
# {'배우이름': '박근수'}
# {'배우이름': '류제승'}
# {'배우이름': '한신화'}
# {'배우이름': '정수지'}
# {'배우이름': '김영삼'}

# %% [markdown]
# ### 1.4 find의 다양한 문법 - 필드값 범위로 검색

# %%
docs = actor.find({'흥행지수': {'$gte': 10000}, '출연영화':'신세계'}, {'배우이름':1, '출연영화':1, '_id':0}).sort('배우이름').limit(3)
for doc in docs:
    print(doc)
# Out:
# {'배우이름': '박성웅', '출연영화': ['오케이 마담', '신세계', '하이힐']}
# {'배우이름': '이정재', '출연영화': ['다만 악에서 구하소서', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연', '사바하', '도둑들']}
# {'배우이름': '황정민', '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라']}

# %% [markdown]
# ### find의 다양한 문법 - or

# %%
docs = actor.find({'$or': [{'출연영화':'신세계'}, {'출연영화':'반도'}] }, {'배우이름':1, '출연영화':1, '_id':0})
for doc in docs:
    print(doc)
# Out:
# {'배우이름': '황정민', '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라']}
# {'배우이름': '이정재', '출연영화': ['다만 악에서 구하소서', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연', '사바하', '도둑들']}
# {'배우이름': '강동원', '출연영화': ['반도', '1987']}
# {'배우이름': '이정현', '출연영화': ['죽지않는 인간들의 밤', '반도', '명량']}
# {'배우이름': '이레', '출연영화': ['너의 이름은.', '반도', '소원', '개를 훔치는 완벽한 방법', '증인']}
# {'배우이름': '권해효', '출연영화': ['도망친 여자', '후쿠오카', '반도', '사이비', '메기', '배심원들']}
# {'배우이름': '구교환', '출연영화': ['메기', '반도']}
# {'배우이름': '박성웅', '출연영화': ['오케이 마담', '신세계', '하이힐']}
# {'배우이름': '김민재', '출연영화': ['국제시장', '반도', '비밀은 없다', '뷰티 인사이드']}
# {'배우이름': '김도윤', '출연영화': ['럭키 몬스터 ', '반도']}
# {'배우이름': '송지효', '출연영화': ['신세계', '침입자']}
# {'배우이름': '장광', '출연영화': ['강철비2: 정상회담', '가나의 혼인잔치: 언약', '매지컬 : 공주를 웃겨라', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연']}
# {'배우이름': '최민식', '출연영화': ['천문: 하늘에 묻는다', '신세계', '올드보이', '범죄와의 전쟁 : 나쁜 놈들 전성시대', '친절한 금자씨', '명량']}
# {'배우이름': '김홍파', '출연영화': ['천문: 하늘에 묻는다', '신세계', '배심원들', '내부자들']}
# {'배우이름': '이경영', '출연영화': ['백두산', '신세계', '신과 함께-죄와 벌', '블랙머니', '불한당: 나쁜 놈들의 세상', '부러진 화살']}
# {'배우이름': '류승범', '출연영화': ['아치와 씨팍', '부당거래', '신세계', '복수는 나의 것', '타짜: 원 아이드 잭']}
# {'배우이름': '김윤성', '출연영화': ['신세계']}
# {'배우이름': '김병옥', '출연영화': ['신세계', '메피스토', '친절한 금자씨', '올드보이', '싸이보그지만 괜찮아', '오래된 정원']}
# {'배우이름': '최일화', '출연영화': ['신세계', '김종욱 찾기', '멋진 하루']}
# {'배우이름': '주진모', '출연영화': ['신세계']}
# {'배우이름': '권태원', '출연영화': ['신세계', '개 같은 것들', '소원']}
# {'배우이름': '우정국', '출연영화': ['신세계']}
# {'배우이름': '박인수', '출연영화': ['신세계']}
# {'배우이름': '정영기', '출연영화': ['신세계']}
# {'배우이름': '박상규', '출연영화': ['신세계']}
# {'배우이름': '함진성', '출연영화': ['신세계']}
# {'배우이름': '박로사', '출연영화': ['신세계']}

# %%
docs = actor.find({ '흥행지수': {'$gte': 10000}, '$or': [{'출연영화':'신세계'}, {'출연영화':'반도'}] }, {'배우이름':1, '출연영화':1, '_id':0})
for doc in docs:
    print(doc)
# Out:
# {'배우이름': '황정민', '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라']}
# {'배우이름': '이정재', '출연영화': ['다만 악에서 구하소서', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연', '사바하', '도둑들']}
# {'배우이름': '강동원', '출연영화': ['반도', '1987']}
# {'배우이름': '이정현', '출연영화': ['죽지않는 인간들의 밤', '반도', '명량']}
# {'배우이름': '이레', '출연영화': ['너의 이름은.', '반도', '소원', '개를 훔치는 완벽한 방법', '증인']}
# {'배우이름': '권해효', '출연영화': ['도망친 여자', '후쿠오카', '반도', '사이비', '메기', '배심원들']}
# {'배우이름': '구교환', '출연영화': ['메기', '반도']}
# {'배우이름': '박성웅', '출연영화': ['오케이 마담', '신세계', '하이힐']}
# {'배우이름': '김민재', '출연영화': ['국제시장', '반도', '비밀은 없다', '뷰티 인사이드']}

# %% [markdown]
# ### find의 다양한 문법 - nor
# * not or

# %%
docs = actor.find({'$nor': [{'흥행지수': { '$gte': 10000}}, {'흥행지수': { '$lte': 2000}}]}, {'배우이름':1, '흥행지수':1, '_id':0}).limit(3)
for doc in docs:
    print (doc)
# Out:
# {'배우이름': '정우성', '흥행지수': 9796}
# {'배우이름': '이상윤', '흥행지수': 8796}
# {'배우이름': '라미란', '흥행지수': 8317}

# %% [markdown]
# ### find의 다양한 문법 - in, nin
# * in: 들어가 있다.
# * nin: not in - 들어가 있지 않다.

# %%
docs = actor.find({'흥행지수': { '$in': [9796, 8317]}}, {'배우이름':1, '흥행지수':1, '_id':0})
for doc in docs:
    print (doc)
# Out:
# {'배우이름': '정우성', '흥행지수': 9796}
# {'배우이름': '라미란', '흥행지수': 8317}

# %%
docs = actor.find({'흥행지수': { '$nin': [9796, 8317]}}, {'배우이름':1, '흥행지수':1, '_id':0}).limit(3)
for doc in docs:
    print (doc)
# Out:
# {'배우이름': '황정민', '흥행지수': 78066}
# {'배우이름': '이정재', '흥행지수': 52049}
# {'배우이름': '유아인', '흥행지수': 42530}

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="blue" size="4em">실습</font><br>
# 흥행지수 가 9796, 8317이 아니고, 10000 이하인 데이터를 3개만 검색하세요. (nor, in, gt 활용, 배우이름과 흥행지수만 출력)
# </div>

# %%
docs = actor.find({ '$nor': [{'흥행지수': { '$in': [9796, 8317] } }, {'흥행지수': {'$gt': 10000} }] }, {'배우이름': 1, '흥행지수': 1, '_id': 0}).limit(3)
for doc in docs:
    print(doc)
# Out:
# {'배우이름': '이상윤', '흥행지수': 8796}
# {'배우이름': '허율', '흥행지수': 7543}
# {'배우이름': '김도윤', '흥행지수': 7345}

# %% [markdown]
# ### find의 다양한 문법 - skip, limit
# * skip(n): 검색 결과 n개만큼 건너뜀
# * limit(n): 검색 결과 n개만 표시

# %%
docs = actor.find({'흥행지수': {'$gte': 10000}}).limit(3)
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1a'), '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '배우이름': '황정민', '흥행지수': 78066, '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라'], '랭킹': 1}
# {'_id': ObjectId('6019112ffd9a8148c2183d1b'), '직업': '배우', '성별': '남', '홈페이지': '\nhttp://www.artistcompany.co.kr/portfolio-item/lee-jung-jae/\n', '소속사': '아티스트컴퍼니', '배우이름': '이정재', '흥행지수': 52049, '출연영화': ['다만 악에서 구하소서', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연', '사바하', '도둑들'], '랭킹': 2}
# {'_id': ObjectId('6019112ffd9a8148c2183d1c'), '직업': '배우', '생년월일': '1986-10-06', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/hongsick/\nhttps://twitter.com/seeksik\n', '신장/체중': '178cm, 60kg', '학교': '단국대학교 연극', '취미': '피아노 연주, 인터넷 게임, 영화, 음악감상', '특기': '스노우보드, 수영', '배우이름': '유아인', '흥행지수': 42530, '출연영화': ['#살아있다', '소리도 없이', '버닝', '사도'], '랭킹': 3, '다른이름': '엄홍식'}

# %%
docs = actor.find({'흥행지수': {'$gte': 10000}}).skip(3)
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1d'), '직업': '배우', '생년월일': '1981-01-18', '성별': '남', '홈페이지': '\nhttp://www.gangdongwon.com\n', '신장/체중': '186cm, 68kg', '학교': '한양대 - 상명대학교대학원 연극영화 (석사과정 재학)', '취미': '음악감상, 웹서핑, 운동, 신발 모으기', '특기': '축구', '배우이름': '강동원', '흥행지수': 29187, '출연영화': ['반도', '1987'], '랭킹': 4}
# {'_id': ObjectId('6019112ffd9a8148c2183d1e'), '직업': '배우', '생년월일': '1980-02-07', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/mermaidleejh/\nhttps://twitter.com/mermaidjh\n', '신장/체중': '158cm, 38kg', '학교': '중앙대학교 연극영화', '취미': '바비 인형 수집, 피아노 연주', '특기': '별관찰, 시나리오 쓰기', '소속사': '에이바 앤 엔터테인먼트', '배우이름': '이정현', '흥행지수': 26559, '출연영화': ['죽지않는 인간들의 밤', '반도', '명량'], '랭킹': 5}
# {'_id': ObjectId('6019112ffd9a8148c2183d1f'), '직업': '배우', '생년월일': '1987-02-25', '성별': '남', '신장/체중': '178cm, 63kg', '학교': '한국예술종합학교 영상원 연극원 연기과', '배우이름': '박정민', '흥행지수': 26048, '출연영화': ['다만 악에서 구하소서', '시동', '사냥의 시간', '들개', '동주', '사바하'], '랭킹': 6}
# {'_id': ObjectId('6019112ffd9a8148c2183d20'), '직업': '배우', '생년월일': '1967-04-27', '성별': '남', '신장/체중': '177cm, 78kg', '학교': '유한대학 기계설계학', '배우이름': '성동일', '흥행지수': 23010, '출연영화': ['담보'], '랭킹': 7}
# {'_id': ObjectId('6019112ffd9a8148c2183d21'), '직업': '배우', '생년월일': '1978-03-11', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/ft.hajungwoo\n', '신장/체중': '184cm, 75kg', '학교': '중앙대학교 연극학 학사', '취미': '피아노, 검도, 수영', '배우이름': '하정우', '흥행지수': 22609, '출연영화': ['클로젯', '백두산', '범죄와의 전쟁 : 나쁜 놈들 전성시대', '멋진 하루', '아가씨', '신과 함께-죄와 벌'], '랭킹': 8, '다른이름': '김성훈; 河正宇'}
# {'_id': ObjectId('6019112ffd9a8148c2183d22'), '직업': '배우', '생년월일': '2006-03-12', '성별': '여', '홈페이지': '\nhttps://www.facebook.com/leere.vv/\n', '배우이름': '이레', '흥행지수': 22004, '출연영화': ['너의 이름은.', '반도', '소원', '개를 훔치는 완벽한 방법', '증인'], '랭킹': 9}
# {'_id': ObjectId('6019112ffd9a8148c2183d23'), '직업': '배우', '생년월일': '1984-07-04', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/saram.leejehoon\n', '신장/체중': '176cm', '학교': '한국예술종합학교 연극원 연기과', '특기': '댄스, 노래, 무술', '소속사': '㈜사람엔터테인먼트', '배우이름': '이제훈', '흥행지수': 21982, '출연영화': ['도굴', '사냥의 시간', '파수꾼', '박열', '건축학개론'], '랭킹': 10}
# {'_id': ObjectId('6019112ffd9a8148c2183d24'), '직업': '배우', '생년월일': '1990-02-18', '성별': '여', '홈페이지': '\nhttps://twitter.com/ssinz\nhttps://www.instagram.com/ssinz7/\n', '신장/체중': '165cm, 45kg', '학교': '중앙대학교 연극영화학 (재학)', '취미': '음악감상', '특기': '댄스', '소속사': '아바 엔터테인먼트', '배우이름': '박신혜', '흥행지수': 20260, '출연영화': ['#살아있다', '7번방의 선물', '뷰티 인사이드', '시라노; 연애조작단'], '랭킹': 11}
# {'_id': ObjectId('6019112ffd9a8148c2183d25'), '직업': '배우', '생년월일': '1965-11-06', '성별': '남', '신장/체중': '170cm, 62kg', '학교': '한양대학교 연극영화학 졸업', '배우이름': '권해효', '흥행지수': 18349, '출연영화': ['도망친 여자', '후쿠오카', '반도', '사이비', '메기', '배심원들'], '랭킹': 12}
# {'_id': ObjectId('6019112ffd9a8148c2183d26'), '직업': '배우', '생년월일': '1978-06-28', '성별': '여', '홈페이지': '\nhttps://twitter.com/hajiwon1023\nhttps://instagram.com/hajiwon1023\n', '신장/체중': '168cm, 45kg', '학교': '단국대학교 연극영화학 학사', '취미': '만화책보기, 소품만들기, 청소하기', '특기': '검도, 골프, 승마, 재즈댄스, 장구춤', '배우이름': '하지원', '흥행지수': 17278, '출연영화': ['담보', '동감'], '랭킹': 13}
# {'_id': ObjectId('6019112ffd9a8148c2183d27'), '직업': '배우', '생년월일': '1979-01-16', '성별': '남', '배우이름': '조우진', '흥행지수': 16475, '출연영화': ['도굴', '서복', '강철비', '내부자들', '창궐', '1987'], '랭킹': 14, '다른이름': '조신제'}
# {'_id': ObjectId('6019112ffd9a8148c2183d28'), '직업': '배우', '생년월일': '1989-00-00', '성별': '여', '홈페이지': '\nhttps://www.facebook.com/shs831\n https://www.instagram.com/shinhs831/\n', '배우이름': '신혜선', '흥행지수': 16243, '출연영화': ['도굴', '결백'], '랭킹': 15}
# {'_id': ObjectId('6019112ffd9a8148c2183d29'), '직업': '배우', '생년월일': '1982-05-22', '성별': '남', '홈페이지': '\nhttps://twitter.com/k_moo\n', '배우이름': '김무열', '흥행지수': 15245, '출연영화': ['정직한 후보', '침입자', '연평해전', '김종욱 찾기'], '랭킹': 16}
# {'_id': ObjectId('6019112ffd9a8148c2183d2a'), '직업': '배우', '생년월일': '1980-03-13', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/kimnamgilngilstory\n', '신장/체중': '184cm, 70kg', '학교': '사이버한국외국어대학교 중국어과', '소속사': '(주)스타제이엔터테인먼트', '배우이름': '김남길', '흥행지수': 15057, '출연영화': ['클로젯'], '랭킹': 17, '다른이름': '이한; 金南佶'}
# {'_id': ObjectId('6019112ffd9a8148c2183d2b'), '직업': '배우', '생년월일': '1971-01-10', '성별': '남', '신장/체중': '180cm', '학교': '서울예술대학 연극과', '소속사': 'DMS커뮤니케이션즈', '배우이름': '김희원', '흥행지수': 15015, '출연영화': ['이웃사촌', '담보', '국제수사', '신의 한 수: 귀수편', '불한당: 나쁜 놈들의 세상', '뷰티 인사이드'], '랭킹': 18}
# {'_id': ObjectId('6019112ffd9a8148c2183d2c'), '직업': '배우', '생년월일': '1969-08-17', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/umaizing/\nhttps://twitter.com/love_tangle\n', '신장/체중': '164cm, 47kg', '학교': '북원여자고등학교', '취미': '향수병 모으기, 영화보기, 책보기', '특기': '메모하기', '배우이름': '엄정화', '흥행지수': 14659, '출연영화': ['오케이 마담'], '랭킹': 19}
# {'_id': ObjectId('6019112ffd9a8148c2183d2d'), '직업': '배우', '생년월일': '1982-12-14', '성별': '남', '배우이름': '구교환', '흥행지수': 14598, '출연영화': ['메기', '반도'], '랭킹': 20}
# {'_id': ObjectId('6019112ffd9a8148c2183d2e'), '직업': '배우', '생년월일': '1974-00-00', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjesdowon\nhttp://twitter.com/kwakbyoungkuy\n', '배우이름': '곽도원', '흥행지수': 12237, '출연영화': ['남산의 부장들', '강철비2: 정상회담', '국제수사', '범죄와의 전쟁 : 나쁜 놈들 전성시대', '강철비', '아수라'], '랭킹': 21, '다른이름': '곽병규'}
# {'_id': ObjectId('6019112ffd9a8148c2183d2f'), '직업': '배우', '생년월일': '1973-01-09', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjessungwoong\n', '신장/체중': '187cm, 79kg', '학교': '한국외국어대학교 법학', '배우이름': '박성웅', '흥행지수': 11740, '출연영화': ['오케이 마담', '신세계', '하이힐'], '랭킹': 22}
# {'_id': ObjectId('6019112ffd9a8148c2183d30'), '직업': '배우', '생년월일': '1941-11-30', '성별': '여', '홈페이지': '\nhttp://www.namuni.kr/\n', '학교': '창덕여자고등학교', '배우이름': '나문희', '흥행지수': 11059, '출연영화': ['정직한 후보', '오! 문희'], '랭킹': 23}
# {'_id': ObjectId('6019112ffd9a8148c2183d31'), '직업': '배우', '생년월일': '1979-03-20', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjesminjae\n', '학교': '한국예술종합학교', '배우이름': '김민재', '흥행지수': 10946, '출연영화': ['국제시장', '반도', '비밀은 없다', '뷰티 인사이드'], '랭킹': 24}

# %%
docs = actor.find({'흥행지수': {'$gte': 10000}}).skip(3).limit(3)
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1d'), '직업': '배우', '생년월일': '1981-01-18', '성별': '남', '홈페이지': '\nhttp://www.gangdongwon.com\n', '신장/체중': '186cm, 68kg', '학교': '한양대 - 상명대학교대학원 연극영화 (석사과정 재학)', '취미': '음악감상, 웹서핑, 운동, 신발 모으기', '특기': '축구', '배우이름': '강동원', '흥행지수': 29187, '출연영화': ['반도', '1987'], '랭킹': 4}
# {'_id': ObjectId('6019112ffd9a8148c2183d1e'), '직업': '배우', '생년월일': '1980-02-07', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/mermaidleejh/\nhttps://twitter.com/mermaidjh\n', '신장/체중': '158cm, 38kg', '학교': '중앙대학교 연극영화', '취미': '바비 인형 수집, 피아노 연주', '특기': '별관찰, 시나리오 쓰기', '소속사': '에이바 앤 엔터테인먼트', '배우이름': '이정현', '흥행지수': 26559, '출연영화': ['죽지않는 인간들의 밤', '반도', '명량'], '랭킹': 5}
# {'_id': ObjectId('6019112ffd9a8148c2183d1f'), '직업': '배우', '생년월일': '1987-02-25', '성별': '남', '신장/체중': '178cm, 63kg', '학교': '한국예술종합학교 영상원 연극원 연기과', '배우이름': '박정민', '흥행지수': 26048, '출연영화': ['다만 악에서 구하소서', '시동', '사냥의 시간', '들개', '동주', '사바하'], '랭킹': 6}

# %% [markdown]
# ### find의 다양한 문법 - list 검색

# %%
docs = actor.find({'출연영화': '신세계'})
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1a'), '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '배우이름': '황정민', '흥행지수': 78066, '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라'], '랭킹': 1}
# {'_id': ObjectId('6019112ffd9a8148c2183d1b'), '직업': '배우', '성별': '남', '홈페이지': '\nhttp://www.artistcompany.co.kr/portfolio-item/lee-jung-jae/\n', '소속사': '아티스트컴퍼니', '배우이름': '이정재', '흥행지수': 52049, '출연영화': ['다만 악에서 구하소서', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연', '사바하', '도둑들'], '랭킹': 2}
# {'_id': ObjectId('6019112ffd9a8148c2183d2f'), '직업': '배우', '생년월일': '1973-01-09', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjessungwoong\n', '신장/체중': '187cm, 79kg', '학교': '한국외국어대학교 법학', '배우이름': '박성웅', '흥행지수': 11740, '출연영화': ['오케이 마담', '신세계', '하이힐'], '랭킹': 22}
# {'_id': ObjectId('6019112ffd9a8148c2183d40'), '직업': '배우', '생년월일': '1981-08-15', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/my_songjihyo/\nhttps://www.facebook.com/MYOFFICIALSONGJIHYO\n', '신장/체중': '168cm, 46kg', '학교': '경문대 세무회계학과', '배우이름': '송지효', '흥행지수': 5729, '출연영화': ['신세계', '침입자'], '랭킹': 39}
# {'_id': ObjectId('6019112ffd9a8148c2183d58'), '직업': '배우', '생년월일': '1952-01-05', '성별': '남', '배우이름': '장광', '흥행지수': 3632, '출연영화': ['강철비2: 정상회담', '가나의 혼인잔치: 언약', '매지컬 : 공주를 웃겨라', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연'], '랭킹': 63}
# {'_id': ObjectId('6019112ffd9a8148c2183e96'), '직업': '배우', '생년월일': '1962-04-27', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjesminsik\n', '신장/체중': '177cm, 70kg', '학교': '동국대학교 연극영화', '취미': '공연 관람, 수집, 그림그리기, 골프', '배우이름': '최민식', '흥행지수': 47, '출연영화': ['천문: 하늘에 묻는다', '신세계', '올드보이', '범죄와의 전쟁 : 나쁜 놈들 전성시대', '친절한 금자씨', '명량'], '랭킹': 381, '다른이름': '崔岷植'}
# {'_id': ObjectId('6019112ffd9a8148c2183ebb'), '직업': '배우', '생년월일': '1962-01-05', '성별': '남', '배우이름': '김홍파', '흥행지수': 31, '출연영화': ['천문: 하늘에 묻는다', '신세계', '배심원들', '내부자들'], '랭킹': 418}
# {'_id': ObjectId('6019112ffd9a8148c2183ebd'), '직업': '배우', '생년월일': '1960-12-12', '성별': '남', '신장/체중': '173cm, 64kg', '학교': '한양대학교 연극영화학 학사', '배우이름': '이경영', '흥행지수': 31, '출연영화': ['백두산', '신세계', '신과 함께-죄와 벌', '블랙머니', '불한당: 나쁜 놈들의 세상', '부러진 화살'], '랭킹': 420}
# {'_id': ObjectId('6019112ffd9a8148c2183f35'), '직업': '배우', '생년월일': '1980-08-09', '성별': '남', '신장/체중': '178cm, 68kg', '학교': '대동상업고등학교 중퇴', '취미': '영화보기, 스노우보드', '특기': '디제잉', '소속사': '웰메이드스타엠', '배우이름': '류승범', '흥행지수': 15, '출연영화': ['아치와 씨팍', '부당거래', '신세계', '복수는 나의 것', '타짜: 원 아이드 잭'], '랭킹': 540}
# {'_id': ObjectId('6019112ffd9a8148c2183f6e'), '직업': '배우', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/actor_henry_\n', '배우이름': '김윤성', '흥행지수': 11, '출연영화': ['신세계'], '랭킹': 597}
# {'_id': ObjectId('6019112ffd9a8148c2183f72'), '직업': '배우', '생년월일': '1960-10-11', '성별': '남', '신장/체중': '170cm, 67kg', '소속사': '싸이더스 HQ', '배우이름': '김병옥', '흥행지수': 11, '출연영화': ['신세계', '메피스토', '친절한 금자씨', '올드보이', '싸이보그지만 괜찮아', '오래된 정원'], '랭킹': 601}
# {'_id': ObjectId('6019112ffd9a8148c2183f7a'), '직업': '배우', '생년월일': '1959-00-00', '성별': '남', '배우이름': '최일화', '흥행지수': 11, '출연영화': ['신세계', '김종욱 찾기', '멋진 하루'], '랭킹': 609}
# {'_id': ObjectId('6019112ffd9a8148c2183f8c'), '직업': '배우', '생년월일': '1958-02-26', '성별': '남', '배우이름': '주진모', '흥행지수': 10, '출연영화': ['신세계'], '랭킹': 627}
# {'_id': ObjectId('6019112ffd9a8148c2183f8f'), '직업': '배우', '생년월일': '1962-08-10', '성별': '남', '배우이름': '권태원', '흥행지수': 9, '출연영화': ['신세계', '개 같은 것들', '소원'], '랭킹': 630}
# {'_id': ObjectId('6019112ffd9a8148c2183fe8'), '직업': '배우', '생년월일': '1974-03-10', '성별': '남', '배우이름': '우정국', '흥행지수': 6, '출연영화': ['신세계'], '랭킹': 719}
# {'_id': ObjectId('6019112ffd9a8148c2184001'), '직업': '배우', '생년월일': '1975-05-18', '성별': '남', '배우이름': '박인수', '흥행지수': 6, '출연영화': ['신세계'], '랭킹': 744}
# {'_id': ObjectId('6019112ffd9a8148c218401b'), '직업': '배우', '생년월일': '1981-10-18', '성별': '남', '배우이름': '정영기', '흥행지수': 5, '출연영화': ['신세계'], '랭킹': 770}
# {'_id': ObjectId('6019112ffd9a8148c2184034'), '직업': '배우', '생년월일': '1951-10-01', '성별': '남', '배우이름': '박상규', '흥행지수': 4, '출연영화': ['신세계'], '랭킹': 795}
# {'_id': ObjectId('6019112ffd9a8148c2184059'), '직업': '배우', '생년월일': '1986-05-29', '성별': '남', '배우이름': '함진성', '흥행지수': 4, '출연영화': ['신세계'], '랭킹': 832}
# {'_id': ObjectId('6019112ffd9a8148c218410f'), '직업': '배우', '생년월일': '1987-05-05', '성별': '여', '배우이름': '박로사', '흥행지수': 1, '출연영화': ['신세계'], '랭킹': 1014}

# %%
docs = actor.find({'$or': [{'출연영화': '신세계'}, {'출연영화': '국제시장'}]})
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1a'), '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '배우이름': '황정민', '흥행지수': 78066, '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라'], '랭킹': 1}
# {'_id': ObjectId('6019112ffd9a8148c2183d1b'), '직업': '배우', '성별': '남', '홈페이지': '\nhttp://www.artistcompany.co.kr/portfolio-item/lee-jung-jae/\n', '소속사': '아티스트컴퍼니', '배우이름': '이정재', '흥행지수': 52049, '출연영화': ['다만 악에서 구하소서', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연', '사바하', '도둑들'], '랭킹': 2}
# {'_id': ObjectId('6019112ffd9a8148c2183d2f'), '직업': '배우', '생년월일': '1973-01-09', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjessungwoong\n', '신장/체중': '187cm, 79kg', '학교': '한국외국어대학교 법학', '배우이름': '박성웅', '흥행지수': 11740, '출연영화': ['오케이 마담', '신세계', '하이힐'], '랭킹': 22}
# {'_id': ObjectId('6019112ffd9a8148c2183d31'), '직업': '배우', '생년월일': '1979-03-20', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjesminjae\n', '학교': '한국예술종합학교', '배우이름': '김민재', '흥행지수': 10946, '출연영화': ['국제시장', '반도', '비밀은 없다', '뷰티 인사이드'], '랭킹': 24}
# {'_id': ObjectId('6019112ffd9a8148c2183d34'), '직업': '배우', '생년월일': '1975-03-06', '성별': '여', '홈페이지': '\nhttps://www.facebook.com/cjesmiran\n', '배우이름': '라미란', '흥행지수': 8317, '출연영화': ['정직한 후보', '국제시장', '친절한 금자씨', '소원', '나의 사랑 나의 신부'], '랭킹': 27}
# {'_id': ObjectId('6019112ffd9a8148c2183d40'), '직업': '배우', '생년월일': '1981-08-15', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/my_songjihyo/\nhttps://www.facebook.com/MYOFFICIALSONGJIHYO\n', '신장/체중': '168cm, 46kg', '학교': '경문대 세무회계학과', '배우이름': '송지효', '흥행지수': 5729, '출연영화': ['신세계', '침입자'], '랭킹': 39}
# {'_id': ObjectId('6019112ffd9a8148c2183d58'), '직업': '배우', '생년월일': '1952-01-05', '성별': '남', '배우이름': '장광', '흥행지수': 3632, '출연영화': ['강철비2: 정상회담', '가나의 혼인잔치: 언약', '매지컬 : 공주를 웃겨라', '신세계', '신과 함께-죄와 벌', '신과 함께-인과 연'], '랭킹': 63}
# {'_id': ObjectId('6019112ffd9a8148c2183d86'), '직업': '배우', '생년월일': '1968-06-15', '성별': '남', '신장/체중': '176cm, 68kg', '학교': '동의대학교 공업디자인 (중퇴)', '소속사': '빌리지엔터테인먼트', '배우이름': '오달수', '흥행지수': 1603, '출연영화': ['이웃사촌', '신과 함께-죄와 벌', '7번방의 선물', '국제시장', '올드보이', '박쥐'], '랭킹': 109}
# {'_id': ObjectId('6019112ffd9a8148c2183e96'), '직업': '배우', '생년월일': '1962-04-27', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjesminsik\n', '신장/체중': '177cm, 70kg', '학교': '동국대학교 연극영화', '취미': '공연 관람, 수집, 그림그리기, 골프', '배우이름': '최민식', '흥행지수': 47, '출연영화': ['천문: 하늘에 묻는다', '신세계', '올드보이', '범죄와의 전쟁 : 나쁜 놈들 전성시대', '친절한 금자씨', '명량'], '랭킹': 381, '다른이름': '崔岷植'}
# {'_id': ObjectId('6019112ffd9a8148c2183ebb'), '직업': '배우', '생년월일': '1962-01-05', '성별': '남', '배우이름': '김홍파', '흥행지수': 31, '출연영화': ['천문: 하늘에 묻는다', '신세계', '배심원들', '내부자들'], '랭킹': 418}
# {'_id': ObjectId('6019112ffd9a8148c2183ebd'), '직업': '배우', '생년월일': '1960-12-12', '성별': '남', '신장/체중': '173cm, 64kg', '학교': '한양대학교 연극영화학 학사', '배우이름': '이경영', '흥행지수': 31, '출연영화': ['백두산', '신세계', '신과 함께-죄와 벌', '블랙머니', '불한당: 나쁜 놈들의 세상', '부러진 화살'], '랭킹': 420}
# {'_id': ObjectId('6019112ffd9a8148c2183f35'), '직업': '배우', '생년월일': '1980-08-09', '성별': '남', '신장/체중': '178cm, 68kg', '학교': '대동상업고등학교 중퇴', '취미': '영화보기, 스노우보드', '특기': '디제잉', '소속사': '웰메이드스타엠', '배우이름': '류승범', '흥행지수': 15, '출연영화': ['아치와 씨팍', '부당거래', '신세계', '복수는 나의 것', '타짜: 원 아이드 잭'], '랭킹': 540}
# {'_id': ObjectId('6019112ffd9a8148c2183f4c'), '직업': '배우', '생년월일': '2009-05-14', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/shin_rina/\n', '배우이름': '신린아', '흥행지수': 13, '출연영화': ['악몽', '국제시장'], '랭킹': 563}
# {'_id': ObjectId('6019112ffd9a8148c2183f6e'), '직업': '배우', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/actor_henry_\n', '배우이름': '김윤성', '흥행지수': 11, '출연영화': ['신세계'], '랭킹': 597}
# {'_id': ObjectId('6019112ffd9a8148c2183f70'), '원어명': '정진영', '직업': '배우', '생년월일': '1964-10-16', '성별': '남', '학교': '서울대학교 국어국문학', '배우이름': '정진영', '흥행지수': 11, '출연영화': ['피원에이치: 새로운 세계의 시작', '7번방의 선물', '국제시장', '왕의 남자', '사바하', '풀잎들'], '랭킹': 599}
# {'_id': ObjectId('6019112ffd9a8148c2183f72'), '직업': '배우', '생년월일': '1960-10-11', '성별': '남', '신장/체중': '170cm, 67kg', '소속사': '싸이더스 HQ', '배우이름': '김병옥', '흥행지수': 11, '출연영화': ['신세계', '메피스토', '친절한 금자씨', '올드보이', '싸이보그지만 괜찮아', '오래된 정원'], '랭킹': 601}
# {'_id': ObjectId('6019112ffd9a8148c2183f7a'), '직업': '배우', '생년월일': '1959-00-00', '성별': '남', '배우이름': '최일화', '흥행지수': 11, '출연영화': ['신세계', '김종욱 찾기', '멋진 하루'], '랭킹': 609}
# {'_id': ObjectId('6019112ffd9a8148c2183f8c'), '직업': '배우', '생년월일': '1958-02-26', '성별': '남', '배우이름': '주진모', '흥행지수': 10, '출연영화': ['신세계'], '랭킹': 627}
# {'_id': ObjectId('6019112ffd9a8148c2183f8f'), '직업': '배우', '생년월일': '1962-08-10', '성별': '남', '배우이름': '권태원', '흥행지수': 9, '출연영화': ['신세계', '개 같은 것들', '소원'], '랭킹': 630}
# {'_id': ObjectId('6019112ffd9a8148c2183fe8'), '직업': '배우', '생년월일': '1974-03-10', '성별': '남', '배우이름': '우정국', '흥행지수': 6, '출연영화': ['신세계'], '랭킹': 719}
# {'_id': ObjectId('6019112ffd9a8148c2184001'), '직업': '배우', '생년월일': '1975-05-18', '성별': '남', '배우이름': '박인수', '흥행지수': 6, '출연영화': ['신세계'], '랭킹': 744}
# {'_id': ObjectId('6019112ffd9a8148c218401b'), '직업': '배우', '생년월일': '1981-10-18', '성별': '남', '배우이름': '정영기', '흥행지수': 5, '출연영화': ['신세계'], '랭킹': 770}
# {'_id': ObjectId('6019112ffd9a8148c2184034'), '직업': '배우', '생년월일': '1951-10-01', '성별': '남', '배우이름': '박상규', '흥행지수': 4, '출연영화': ['신세계'], '랭킹': 795}
# {'_id': ObjectId('6019112ffd9a8148c2184059'), '직업': '배우', '생년월일': '1986-05-29', '성별': '남', '배우이름': '함진성', '흥행지수': 4, '출연영화': ['신세계'], '랭킹': 832}
# {'_id': ObjectId('6019112ffd9a8148c21840d1'), '원어명': '장영남', '직업': '배우', '생년월일': '1973-11-25', '성별': '여', '소속사': '멘토엔터테인먼트', '배우이름': '장영남', '흥행지수': 2, '출연영화': ['국제시장', '서복', '증인', '협상', '김종욱 찾기'], '랭킹': 952}
# {'_id': ObjectId('6019112ffd9a8148c218410f'), '직업': '배우', '생년월일': '1987-05-05', '성별': '여', '배우이름': '박로사', '흥행지수': 1, '출연영화': ['신세계'], '랭킹': 1014}
# {'_id': ObjectId('6019112ffd9a8148c2184123'), '직업': '배우', '생년월일': '1973-11-07', '성별': '여', '홈페이지': '\nhttps://www.yunjinkim.co.kr:9023/profile/\n', '신장/체중': '168cm, 48kg', '학교': '보스턴대학교 공연예술학', '취미': '음악감상, 여행', '특기': '발레, 재즈무용', '소속사': '자이온 이엔티(주)', '배우이름': '김윤진', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1034, '다른이름': 'Kim Yun Jin; Kim Yun-Jin'}
# {'_id': ObjectId('6019112ffd9a8148c2184126'), '직업': '배우', '생년월일': '1973-11-07', '성별': '여', '홈페이지': '\nhttps://www.yunjinkim.co.kr:9023/profile/\n', '신장/체중': '168cm, 48kg', '학교': '보스턴대학교 공연예술학', '취미': '음악감상, 여행', '특기': '발레, 재즈무용', '소속사': '자이온 이엔티(주)', '배우이름': '김윤진', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1037, '다른이름': 'Kim Yun Jin; Kim Yun-Jin'}
# {'_id': ObjectId('6019112ffd9a8148c2184134'), '직업': '배우', '생년월일': '2003-12-17', '성별': '남', '신장/체중': '158cm', '학교': '2014 경덕 초등학교 수영선수', '배우이름': '유재상', '흥행지수': 1, '출연영화': ['4등', '국제시장'], '랭킹': 1051}
# {'_id': ObjectId('6019112ffd9a8148c2184146'), '직업': '배우', '생년월일': '1980-05-02', '성별': '남', '배우이름': '태인호', '흥행지수': 1, '출연영화': ['국제시장', '배심원들', '니나 내나'], '랭킹': 1069, '다른이름': '박상연'}
# {'_id': ObjectId('6019112ffd9a8148c218418c'), '직업': '배우', '생년월일': '1991-10-10', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/s911010/\nhttps://twitter.com/s911010\n', '배우이름': '김슬기', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1139}
# {'_id': ObjectId('6019112ffd9a8148c218418f'), '직업': '배우', '생년월일': '1991-10-10', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/s911010/\nhttps://twitter.com/s911010\n', '배우이름': '김슬기', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1142}
# {'_id': ObjectId('6019112ffd9a8148c21841e3'), '직업': '배우', '생년월일': '1983-05-28', '성별': '여', '배우이름': '황선화', '흥행지수': 0, '출연영화': ['국제시장'], '랭킹': 1226}
# {'_id': ObjectId('6019112ffd9a8148c2184224'), '직업': '배우', '생년월일': '2003-00-00', '성별': '남', '배우이름': '엄지성', '흥행지수': 0, '출연영화': ['국제시장'], '랭킹': 1291}
# {'_id': ObjectId('6019112ffd9a8148c218422e'), '직업': '배우', '생년월일': '2003-00-00', '성별': '남', '배우이름': '엄지성', '흥행지수': 0, '출연영화': ['국제시장'], '랭킹': 1301}
# {'_id': ObjectId('6019112ffd9a8148c218429a'), '직업': '배우', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/dlgus20\n', '배우이름': '이현', '흥행지수': 0, '출연영화': ['국제시장'], '랭킹': 1409}

# %% [markdown]
# ### find의 다양한 문법 - list 검색 (all)

# %%
docs = actor.find({'출연영화': { '$all': ['신세계', '국제시장']}})
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1a'), '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '배우이름': '황정민', '흥행지수': 78066, '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라'], '랭킹': 1}

# %% [markdown]
# ### find의 다양한 문법 - list 검색 (리스트 index 번호로 검색하기)

# %%
docs = actor.find({'출연영화.0': '국제시장'})
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d31'), '직업': '배우', '생년월일': '1979-03-20', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjesminjae\n', '학교': '한국예술종합학교', '배우이름': '김민재', '흥행지수': 10946, '출연영화': ['국제시장', '반도', '비밀은 없다', '뷰티 인사이드'], '랭킹': 24}
# {'_id': ObjectId('6019112ffd9a8148c21840d1'), '원어명': '장영남', '직업': '배우', '생년월일': '1973-11-25', '성별': '여', '소속사': '멘토엔터테인먼트', '배우이름': '장영남', '흥행지수': 2, '출연영화': ['국제시장', '서복', '증인', '협상', '김종욱 찾기'], '랭킹': 952}
# {'_id': ObjectId('6019112ffd9a8148c2184123'), '직업': '배우', '생년월일': '1973-11-07', '성별': '여', '홈페이지': '\nhttps://www.yunjinkim.co.kr:9023/profile/\n', '신장/체중': '168cm, 48kg', '학교': '보스턴대학교 공연예술학', '취미': '음악감상, 여행', '특기': '발레, 재즈무용', '소속사': '자이온 이엔티(주)', '배우이름': '김윤진', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1034, '다른이름': 'Kim Yun Jin; Kim Yun-Jin'}
# {'_id': ObjectId('6019112ffd9a8148c2184126'), '직업': '배우', '생년월일': '1973-11-07', '성별': '여', '홈페이지': '\nhttps://www.yunjinkim.co.kr:9023/profile/\n', '신장/체중': '168cm, 48kg', '학교': '보스턴대학교 공연예술학', '취미': '음악감상, 여행', '특기': '발레, 재즈무용', '소속사': '자이온 이엔티(주)', '배우이름': '김윤진', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1037, '다른이름': 'Kim Yun Jin; Kim Yun-Jin'}
# {'_id': ObjectId('6019112ffd9a8148c2184146'), '직업': '배우', '생년월일': '1980-05-02', '성별': '남', '배우이름': '태인호', '흥행지수': 1, '출연영화': ['국제시장', '배심원들', '니나 내나'], '랭킹': 1069, '다른이름': '박상연'}
# {'_id': ObjectId('6019112ffd9a8148c218418c'), '직업': '배우', '생년월일': '1991-10-10', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/s911010/\nhttps://twitter.com/s911010\n', '배우이름': '김슬기', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1139}
# {'_id': ObjectId('6019112ffd9a8148c218418f'), '직업': '배우', '생년월일': '1991-10-10', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/s911010/\nhttps://twitter.com/s911010\n', '배우이름': '김슬기', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1142}
# {'_id': ObjectId('6019112ffd9a8148c21841e3'), '직업': '배우', '생년월일': '1983-05-28', '성별': '여', '배우이름': '황선화', '흥행지수': 0, '출연영화': ['국제시장'], '랭킹': 1226}
# {'_id': ObjectId('6019112ffd9a8148c2184224'), '직업': '배우', '생년월일': '2003-00-00', '성별': '남', '배우이름': '엄지성', '흥행지수': 0, '출연영화': ['국제시장'], '랭킹': 1291}
# {'_id': ObjectId('6019112ffd9a8148c218422e'), '직업': '배우', '생년월일': '2003-00-00', '성별': '남', '배우이름': '엄지성', '흥행지수': 0, '출연영화': ['국제시장'], '랭킹': 1301}
# {'_id': ObjectId('6019112ffd9a8148c218429a'), '직업': '배우', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/dlgus20\n', '배우이름': '이현', '흥행지수': 0, '출연영화': ['국제시장'], '랭킹': 1409}

# %% [markdown]
# ### find의 다양한 문법 - list 검색 (리스트 사이즈로 검색하기)

# %%
docs = actor.find({'출연영화': {'$size': 5}})
for doc in docs:
    print(doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1a'), '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '배우이름': '황정민', '흥행지수': 78066, '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라'], '랭킹': 1}
# {'_id': ObjectId('6019112ffd9a8148c2183d22'), '직업': '배우', '생년월일': '2006-03-12', '성별': '여', '홈페이지': '\nhttps://www.facebook.com/leere.vv/\n', '배우이름': '이레', '흥행지수': 22004, '출연영화': ['너의 이름은.', '반도', '소원', '개를 훔치는 완벽한 방법', '증인'], '랭킹': 9}
# {'_id': ObjectId('6019112ffd9a8148c2183d23'), '직업': '배우', '생년월일': '1984-07-04', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/saram.leejehoon\n', '신장/체중': '176cm', '학교': '한국예술종합학교 연극원 연기과', '특기': '댄스, 노래, 무술', '소속사': '㈜사람엔터테인먼트', '배우이름': '이제훈', '흥행지수': 21982, '출연영화': ['도굴', '사냥의 시간', '파수꾼', '박열', '건축학개론'], '랭킹': 10}
# {'_id': ObjectId('6019112ffd9a8148c2183d34'), '직업': '배우', '생년월일': '1975-03-06', '성별': '여', '홈페이지': '\nhttps://www.facebook.com/cjesmiran\n', '배우이름': '라미란', '흥행지수': 8317, '출연영화': ['정직한 후보', '국제시장', '친절한 금자씨', '소원', '나의 사랑 나의 신부'], '랭킹': 27}
# {'_id': ObjectId('6019112ffd9a8148c2183d38'), '직업': '배우', '생년월일': '1986-12-24', '성별': '남', '학교': '한국예술종합학교 예술사', '배우이름': '조현철', '흥행지수': 6794, '출연영화': ['삼진그룹 영어토익반', '이웃사촌', '초행', '영화로운 나날', '건축학개론'], '랭킹': 31}
# {'_id': ObjectId('6019112ffd9a8148c2183d39'), '직업': '배우', '생년월일': '1979-06-29', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/official.leeheejun\n', '배우이름': '이희준', '흥행지수': 6764, '출연영화': ['남산의 부장들', '오! 문희', '환상속의 그대', '최악의 하루', '1987'], '랭킹': 32}
# {'_id': ObjectId('6019112ffd9a8148c2183d3f'), '직업': '배우', '생년월일': '1984-04-11', '성별': '남', '홈페이지': '\nhttps://twitter.com/yeonseok411\nhttps://www.instagram.com/yoo_yeonseok/\n', '소속사': '이야기엔터테인먼트', '배우이름': '유연석', '흥행지수': 5759, '출연영화': ['강철비2: 정상회담', '새해전야', '제보자', '건축학개론', '뷰티 인사이드'], '랭킹': 38, '다른이름': '안연석'}
# {'_id': ObjectId('6019112ffd9a8148c2183d50'), '직업': '배우', '생년월일': '1968-10-15', '성별': '남', '신장/체중': '178cm', '배우이름': '이성민', '흥행지수': 4393, '출연영화': ['남산의 부장들', '미스터 주: 사라진 VIP', '부당거래', '뺑반', '밀양'], '랭킹': 55}
# {'_id': ObjectId('6019112ffd9a8148c2183d53'), '직업': '배우', '생년월일': '1955-03-25', '성별': '여', '배우이름': '예수정', '흥행지수': 3934, '출연영화': ['69세', '침입자', '어게인', '허스토리 ', '죽여주는 여자'], '랭킹': 58}
# {'_id': ObjectId('6019112ffd9a8148c2183d5c'), '직업': '배우', '생년월일': '1973-05-13', '성별': '남', '배우이름': '조한철', '흥행지수': 3482, '출연영화': ['정직한 후보', '백두산', '블랙머니', '배심원들', '신과 함께-인과 연'], '랭킹': 67}
# {'_id': ObjectId('6019112ffd9a8148c2183d61'), '직업': '배우', '생년월일': '1964-12-25', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/Annaesang/\n', '학교': '연세대학교 신학', '배우이름': '안내상', '흥행지수': 3327, '출연영화': ['강철비2: 정상회담', '저 산 너머', '오아시스', '시', '아내를 죽였다'], '랭킹': 72}
# {'_id': ObjectId('6019112ffd9a8148c2183d72'), '직업': '배우', '생년월일': '1980-12-16', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/daemyeung.kim/\n', '배우이름': '김대명', '흥행지수': 2318, '출연영화': ['국제수사', '돌멩이', '해빙', '내부자들', '뷰티 인사이드'], '랭킹': 89}
# {'_id': ObjectId('6019112ffd9a8148c2183d85'), '직업': '배우', '생년월일': '1977-11-29', '성별': '여', '학교': '단국대학교 연극영화과', '배우이름': '신동미', '흥행지수': 1613, '출연영화': ['국제수사', '영하의 바람', '사라진 시간', '끝까지 간다', '보희와 녹양'], '랭킹': 108, '다른이름': '유하진'}
# {'_id': ObjectId('6019112ffd9a8148c2183da2'), '직업': '배우', '생년월일': '1975-03-02', '성별': '남', '신장/체중': '180cm, 70kg', '학교': '한국예술종합학교 연극', '취미': '만화책보기', '소속사': '호두엔터테인먼트', '배우이름': '이선균', '흥행지수': 1068, '출연영화': ['기생충', '미스터 주: 사라진 VIP', '끝까지 간다', '우리 선희', '누구의 딸도 아닌 해원'], '랭킹': 137}
# {'_id': ObjectId('6019112ffd9a8148c2183df4'), '직업': '성우', '생년월일': '1978-04-17', '성별': '여', '배우이름': '박지윤', '흥행지수': 320, '출연영화': ['추억의 검정고무신', '마이 리틀 포니 : 레인보우 로드 트립', '매지컬 : 공주를 웃겨라', '눈의 여왕4', '겨울왕국'], '랭킹': 219}
# {'_id': ObjectId('6019112ffd9a8148c2183df9'), '직업': '성우', '성별': '여', '배우이름': '소연', '흥행지수': 291, '출연영화': ['극장판 미니특공대: 공룡왕 디노', '극장판 엉덩이 탐정: 텐텐마을의 수수께끼', '극장판 원피스 스탬피드', '극장판 엉덩이 탐정: 화려한 사건 수첩', '겨울왕국'], '랭킹': 224}
# {'_id': ObjectId('6019112ffd9a8148c2183e1d'), '직업': '성우', '성별': '남', '배우이름': '정재헌', '흥행지수': 189, '출연영화': ['극장판 바다 탐험대 옥토넛: 대산호초 보호작전', '극장판 원피스 스탬피드', '레드슈즈', '하이큐!! 재능과 센스', '극장판 유희왕 더 다크 사이드 오브 디멘션즈'], '랭킹': 260}
# {'_id': ObjectId('6019112ffd9a8148c2183e32'), '직업': '성우', '생년월일': '1982-02-09', '성별': '남', '배우이름': '심규혁', '흥행지수': 156, '출연영화': ['날씨의 아이', '극장판 원피스 스탬피드', '하이큐!! 재능과 센스', '괴물의 아이', '프린스 코기'], '랭킹': 281}
# {'_id': ObjectId('6019112ffd9a8148c2183e34'), '직업': '배우', '생년월일': '1970-00-00', '성별': '남', '배우이름': '최덕문', '흥행지수': 149, '출연영화': ['블랙머니', '애비규환', '소공녀', '사도', '애월'], '랭킹': 283}
# {'_id': ObjectId('6019112ffd9a8148c2183e75'), '직업': '배우', '생년월일': '1976-04-13', '성별': '남', '신장/체중': '186cm, 74kg', '학교': '단국대 연극영화과 - 중앙대첨단영상대학원 영상예술학', '취미': '사진촬영, 음악감상', '소속사': '지티비엔터테인먼트', '배우이름': '유지태', '흥행지수': 70, '출연영화': ['봄날은 간다', '동감', '올드보이', '친절한 금자씨', '사바하'], '랭킹': 348, '다른이름': '劉智泰'}
# {'_id': ObjectId('6019112ffd9a8148c2183e7e'), '직업': '성우', '성별': '여', '배우이름': '김현지', '흥행지수': 64, '출연영화': ['극장판 요괴워치: 포에버 프렌즈', '뽀로로 극장판 보물섬 대모험', '신비아파트 극장판 하늘도깨비 대 요르문간드', '하이큐!! 재능과 센스', '프린스 코기'], '랭킹': 357}
# {'_id': ObjectId('6019112ffd9a8148c2183e82'), '직업': '배우', '생년월일': '1970-00-00', '성별': '남', '홈페이지': '\nhttps://twitter.com/yoonjemoon\n', '신장/체중': '180cm', '소속사': '나무액터스', '배우이름': '윤제문', '흥행지수': 59, '출연영화': ['천문: 하늘에 묻는다', '고령화가족', '후쿠오카', '마더', '타짜: 원 아이드 잭'], '랭킹': 361}
# {'_id': ObjectId('6019112ffd9a8148c2183f1b'), '직업': '배우', '생년월일': '1962-08-28', '성별': '남', '신장/체중': '171cm, 60kg', '소속사': '싸이더스 HQ', '배우이름': '오광록', '흥행지수': 17, '출연영화': ['천문: 하늘에 묻는다', '악몽', '올드보이', '친절한 금자씨', '복수는 나의 것'], '랭킹': 514}
# {'_id': ObjectId('6019112ffd9a8148c2183f35'), '직업': '배우', '생년월일': '1980-08-09', '성별': '남', '신장/체중': '178cm, 68kg', '학교': '대동상업고등학교 중퇴', '취미': '영화보기, 스노우보드', '특기': '디제잉', '소속사': '웰메이드스타엠', '배우이름': '류승범', '흥행지수': 15, '출연영화': ['아치와 씨팍', '부당거래', '신세계', '복수는 나의 것', '타짜: 원 아이드 잭'], '랭킹': 540}
# {'_id': ObjectId('6019112ffd9a8148c2183f6f'), '직업': '배우', '생년월일': '1955-00-00', '성별': '남', '배우이름': '김종구', '흥행지수': 11, '출연영화': ['욕창', '시', '엑시트', '들개', '정'], '랭킹': 598}
# {'_id': ObjectId('6019112ffd9a8148c2183fa3'), '직업': '배우', '생년월일': '1985-07-22', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/dlehdgnl/\n', '배우이름': '이동휘', '흥행지수': 9, '출연영화': ['극한직업', '국도극장', '어린 의뢰인', '새해전야', '아가씨'], '랭킹': 650}
# {'_id': ObjectId('6019112ffd9a8148c2183fe6'), '직업': '배우', '생년월일': '1934-08-01', '성별': '남', '학교': '한양대학교 화학공학과', '배우이름': '남궁원', '흥행지수': 6, '출연영화': ['실록 김두한', '삼일천하', '산딸기', '내시', '빨간 마후라'], '랭킹': 717, '다른이름': '홍경일'}
# {'_id': ObjectId('6019112ffd9a8148c21840b0'), '직업': '배우', '생년월일': '1936-03-20', '성별': '여', '학교': '숙명여자대학교 가정학 학사', '배우이름': '엄앵란', '흥행지수': 2, '출연영화': ['맨발의 청춘', '마부', '하녀', '언니는 말괄량이', '동심초'], '랭킹': 919, '다른이름': '엄인기'}
# {'_id': ObjectId('6019112ffd9a8148c21840d1'), '원어명': '장영남', '직업': '배우', '생년월일': '1973-11-25', '성별': '여', '소속사': '멘토엔터테인먼트', '배우이름': '장영남', '흥행지수': 2, '출연영화': ['국제시장', '서복', '증인', '협상', '김종욱 찾기'], '랭킹': 952}
# {'_id': ObjectId('6019112ffd9a8148c218411d'), '직업': '배우', '생년월일': '1935-05-10', '사망': '2015-02-06', '성별': '남', '학교': '경남대학교 법률학과 학사', '배우이름': '이대엽', '흥행지수': 1, '출연영화': ['이조잔영', '촌색씨', '돌아오지 않는 해병', '언니는 말괄량이', '빨간 마후라'], '랭킹': 1028}
# {'_id': ObjectId('6019112ffd9a8148c218415d'), '직업': '배우', '생년월일': '1964-03-28', '성별': '여', '배우이름': '박명신', '흥행지수': 1, '출연영화': ['오아시스', '친절한 금자씨', '시', '올드보이', '사도'], '랭킹': 1092}

# %% [markdown]
# ### find의 다양한 문법 (elemMatch)
# * 적어도 한 개 이상의 리스트 요소가 복수 개의 조건을 동시에 만족하는 경우

# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import re

conn = pymongo.MongoClient()
actor_db = conn.cine21
elemmatch_sample = actor_db.sample

# %%
elemmatch_sample.insert_many([
    {'results': [82, 85, 88]},
    {'results': [75, 88, 91]}
])

# %%
docs = elemmatch_sample.find({'results': {'$gte': 90, '$lt':85}})
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('60192bc8b07f196e1bbe7220'), 'results': [75, 88, 91]}

# %%
docs = elemmatch_sample.find({'results': {'$elemMatch': {'$gte':75, '$lt':80}}})
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('60192bc8b07f196e1bbe7220'), 'results': [75, 88, 91]}

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="blue" size="4em">실습</font><br>
# 직업이 가수인 배우 중, 흥행지수가 가장 높은 배우순으로 10명을 출력하세요
# </div>

# %%
docs = actor.find({'직업':'가수'}).sort('흥행지수', pymongo.DESCENDING).limit(10)
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d60'), '직업': '가수', '생년월일': '1991-10-02', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/hojoongng/\n', '배우이름': '김호중', '흥행지수': 3332, '출연영화': ['그대, 고맙소 : 김호중 생애 첫 팬미팅 무비'], '랭킹': 71}
# {'_id': ObjectId('6019112ffd9a8148c2183d8b'), '직업': '가수', '생년월일': '1991-06-16', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/im_hero____\n', '배우이름': '임영웅', '흥행지수': 1471, '출연영화': ['미스터트롯: 더 무비'], '랭킹': 114}
# {'_id': ObjectId('6019112ffd9a8148c2183d9d'), '원어명': '박영탁', '직업': '가수', '생년월일': '1983-05-13', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/zerotak2\n', '신장/체중': '179cm / 64kg', '배우이름': '영탁', '흥행지수': 1226, '출연영화': ['미스터트롯: 더 무비'], '랭킹': 132}
# {'_id': ObjectId('6019112ffd9a8148c2183d9e'), '직업': '가수', '생년월일': '1994-09-12', '성별': '남', '배우이름': 'RM', '흥행지수': 1148, '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비'], '랭킹': 133, '다른이름': '김남준; 방탄소년단; RM'}
# {'_id': ObjectId('6019112ffd9a8148c2183da4'), '직업': '가수', '생년월일': '1992-12-04', '성별': '남', '배우이름': '진', '흥행지수': 984, '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비'], '랭킹': 139, '다른이름': '김석진; 방탄소년단'}
# {'_id': ObjectId('6019112ffd9a8148c2183da5'), '직업': '가수', '생년월일': '1996-00-00', '성별': '남', '홈페이지': '\nhttps://www.instagram.com/mee_woon_sanae\n', '배우이름': '이찬원', '흥행지수': 981, '출연영화': ['미스터트롯: 더 무비'], '랭킹': 140}
# {'_id': ObjectId('6019112ffd9a8148c2183db3'), '직업': '가수', '생년월일': '1993-03-09', '성별': '남', '배우이름': '슈가', '흥행지수': 820, '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비'], '랭킹': 154, '다른이름': '민윤기; 방탄소년단'}
# {'_id': ObjectId('6019112ffd9a8148c2183db8'), '직업': '가수', '생년월일': '2007-03-19', '성별': '남', '배우이름': '정동원', '흥행지수': 736, '출연영화': ['미스터트롯: 더 무비'], '랭킹': 159}
# {'_id': ObjectId('6019112ffd9a8148c2183dc2'), '직업': '가수', '생년월일': '1994-02-18', '성별': '남', '배우이름': '제이홉', '흥행지수': 656, '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비'], '랭킹': 169, '다른이름': '정호석; 방탄소년단'}
# {'_id': ObjectId('6019112ffd9a8148c2183dc8'), '직업': '가수', '생년월일': '1990-11-29', '성별': '남', '배우이름': '이민혁', '흥행지수': 626, '출연영화': ['검객'], '랭킹': 175, '다른이름': '비투비'}

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="blue" size="4em">실습</font><br>
# 국제시장에 출연한 배우를 흥행지수가 높은 순으로 10명 출력하세요
# </div>

# %%
docs = actor.find({'출연영화':'국제시장'}).sort('흥행지수', pymongo.DESCENDING).limit(10)
for doc in docs:
    print (doc)
# Out:
# {'_id': ObjectId('6019112ffd9a8148c2183d1a'), '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '배우이름': '황정민', '흥행지수': 78066, '출연영화': ['다만 악에서 구하소서', '신세계', '부당거래', '국제시장', '아수라'], '랭킹': 1}
# {'_id': ObjectId('6019112ffd9a8148c2183d31'), '직업': '배우', '생년월일': '1979-03-20', '성별': '남', '홈페이지': '\nhttps://www.facebook.com/cjesminjae\n', '학교': '한국예술종합학교', '배우이름': '김민재', '흥행지수': 10946, '출연영화': ['국제시장', '반도', '비밀은 없다', '뷰티 인사이드'], '랭킹': 24}
# {'_id': ObjectId('6019112ffd9a8148c2183d34'), '직업': '배우', '생년월일': '1975-03-06', '성별': '여', '홈페이지': '\nhttps://www.facebook.com/cjesmiran\n', '배우이름': '라미란', '흥행지수': 8317, '출연영화': ['정직한 후보', '국제시장', '친절한 금자씨', '소원', '나의 사랑 나의 신부'], '랭킹': 27}
# {'_id': ObjectId('6019112ffd9a8148c2183d86'), '직업': '배우', '생년월일': '1968-06-15', '성별': '남', '신장/체중': '176cm, 68kg', '학교': '동의대학교 공업디자인 (중퇴)', '소속사': '빌리지엔터테인먼트', '배우이름': '오달수', '흥행지수': 1603, '출연영화': ['이웃사촌', '신과 함께-죄와 벌', '7번방의 선물', '국제시장', '올드보이', '박쥐'], '랭킹': 109}
# {'_id': ObjectId('6019112ffd9a8148c2183f4c'), '직업': '배우', '생년월일': '2009-05-14', '성별': '여', '홈페이지': '\nhttps://www.instagram.com/shin_rina/\n', '배우이름': '신린아', '흥행지수': 13, '출연영화': ['악몽', '국제시장'], '랭킹': 563}
# {'_id': ObjectId('6019112ffd9a8148c2183f70'), '원어명': '정진영', '직업': '배우', '생년월일': '1964-10-16', '성별': '남', '학교': '서울대학교 국어국문학', '배우이름': '정진영', '흥행지수': 11, '출연영화': ['피원에이치: 새로운 세계의 시작', '7번방의 선물', '국제시장', '왕의 남자', '사바하', '풀잎들'], '랭킹': 599}
# {'_id': ObjectId('6019112ffd9a8148c21840d1'), '원어명': '장영남', '직업': '배우', '생년월일': '1973-11-25', '성별': '여', '소속사': '멘토엔터테인먼트', '배우이름': '장영남', '흥행지수': 2, '출연영화': ['국제시장', '서복', '증인', '협상', '김종욱 찾기'], '랭킹': 952}
# {'_id': ObjectId('6019112ffd9a8148c2184134'), '직업': '배우', '생년월일': '2003-12-17', '성별': '남', '신장/체중': '158cm', '학교': '2014 경덕 초등학교 수영선수', '배우이름': '유재상', '흥행지수': 1, '출연영화': ['4등', '국제시장'], '랭킹': 1051}
# {'_id': ObjectId('6019112ffd9a8148c2184126'), '직업': '배우', '생년월일': '1973-11-07', '성별': '여', '홈페이지': '\nhttps://www.yunjinkim.co.kr:9023/profile/\n', '신장/체중': '168cm, 48kg', '학교': '보스턴대학교 공연예술학', '취미': '음악감상, 여행', '특기': '발레, 재즈무용', '소속사': '자이온 이엔티(주)', '배우이름': '김윤진', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1037, '다른이름': 'Kim Yun Jin; Kim Yun-Jin'}
# {'_id': ObjectId('6019112ffd9a8148c2184123'), '직업': '배우', '생년월일': '1973-11-07', '성별': '여', '홈페이지': '\nhttps://www.yunjinkim.co.kr:9023/profile/\n', '신장/체중': '168cm, 48kg', '학교': '보스턴대학교 공연예술학', '취미': '음악감상, 여행', '특기': '발레, 재즈무용', '소속사': '자이온 이엔티(주)', '배우이름': '김윤진', '흥행지수': 1, '출연영화': ['국제시장'], '랭킹': 1034, '다른이름': 'Kim Yun Jin; Kim Yun-Jin'}
